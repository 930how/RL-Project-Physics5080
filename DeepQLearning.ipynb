# %% [markdown]
# ## Deep Q-Learning Algorithm - Single Inverted Pendulum

# %%
# !pip install gymnasium
# Out:
# Requirement already satisfied: gymnasium in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium) (1.23.5)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium) (0.0.4)

# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# env = gym.make("CartPole-v1", render_mode="human")
env = gym.make("CartPole-v1")

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)
    
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005
LR = 1e-4

# Get number of actions from gym action space
n_actions = env.action_space.n
# Get the number of state observations
state, info = env.reset()
n_observations = len(state)

policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations(show_result=False):
    plt.figure(1)
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())


def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
if torch.cuda.is_available() or torch.backends.mps.is_available():
    num_episodes = 600
else:
    num_episodes = 50

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, info = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    for t in count():
        action = select_action(state)
        observation, reward, terminated, truncated, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)
        done = terminated or truncated

        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)

        if done:
            episode_durations.append(t + 1)
            plot_durations()
            break

print('Complete')
plot_durations(show_result=True)
plt.ioff()
plt.show()
# Out:
# Complete

# %% [markdown]
# ## break

# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# env2 = gym.make("Acrobot-v1", render_mode="human")
env2 = gym.make("Acrobot-v1")

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "mps" if torch.backends.mps.is_available() else
    "cpu"
)

Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)
    
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005
LR = 1e-4

# Get number of actions from gym action space
n_actions = env2.action_space.n
# Get the number of state observations
state, info = env2.reset()
n_observations = len(state)

policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        return torch.tensor([[env2.action_space.sample()]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations(show_result=False):
    plt.figure(1)
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())


def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
if torch.cuda.is_available() or torch.backends.mps.is_available():
    num_episodes = 600
else:
    num_episodes = 50

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, info = env2.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    for t in count():
        action = select_action(state)
        observation, reward, terminated, truncated, _ = env2.step(action.item())
        reward = torch.tensor([reward], device=device)
        done = terminated or truncated

        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)

        if done:
            episode_durations.append(t + 1)
            plot_durations()
            break

print('Complete')
plot_durations(show_result=True)
plt.ioff()
plt.show()
# Out:
# Complete

# %% [markdown]
# ## Deep Q-Learning - Double Inverted Pendulum (Trying Normal Single Pendulum First)

# %%
# !pip install gymnasium[mujoco]
# Out:
# Requirement already satisfied: gymnasium[mujoco] in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (1.23.5)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (0.0.4)
# Requirement already satisfied: mujoco>=2.3.2 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (3.2.5)
# Requirement already satisfied: imageio>=2.14.1 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from gymnasium[mujoco]) (2.36.1)
# Requirement already satisfied: pillow>=8.3.2 in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from imageio>=2.14.1->gymnasium[mujoco]) (10.4.0)
# Requirement already satisfied: absl-py in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from mujoco>=2.3.2->gymnasium[mujoco]) (2.1.0)
# Requirement already satisfied: etils[epath] in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from mujoco>=2.3.2->gymnasium[mujoco]) (1.11.0)
# Requirement already satisfied: glfw in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from mujoco>=2.3.2->gymnasium[mujoco]) (2.8.0)
# Requirement already satisfied: pyopengl in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from mujoco>=2.3.2->gymnasium[mujoco]) (3.1.7)
# Requirement already satisfied: fsspec in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from etils[epath]->mujoco>=2.3.2->gymnasium[mujoco]) (2024.6.1)
# Requirement already satisfied: importlib_resources in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from etils[epath]->mujoco>=2.3.2->gymnasium[mujoco]) (6.4.5)
# Requirement already satisfied: zipp in /home/will/anaconda3/envs/tf/lib/python3.11/site-packages (from etils[epath]->mujoco>=2.3.2->gymnasium[mujoco]) (3.20.2)

# %%
import gymnasium as gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np

# env3 = gym.make("InvertedDoublePendulum-v5")
env3 = gym.make("InvertedPendulum-v5", render_mode="human")


# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

# if GPU is to be used
device = torch.device(
    "cuda" if torch.cuda.is_available() else
    "cpu"
)

# %%
Transition = namedtuple('Transition',('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
# def action_integer(act):
#     if act < 0:
#         return 0
#     else: return 1

def closest_index(array, value):
    idx = torch.argmin(torch.abs(array - value))
    return idx

def closest_value(array, value):
    """Finds the closest element in the array to the given value."""
    idx = closest_index(array, value)
    return array[idx]

def array_to_index(array_space, array):
    result = torch.empty(array.shape, device=device)
    for i in range(array.shape[0]):
        result[i] = ((closest_index(array_space, array[i][0])))
    # return result.astype(int)
    return result.to(int)

# action_space = torch.linspace(-3, 3, 50, device=device)

# test_array = np.array([[-1.1633],
#         [-3.0000],
#         [-1.8980],
#         [ 1.2857],
#         [16.0000],
#         [ 1.6531],
#         [-1.5306],
#         [-1.2857],
#         [39.0000],
#         [-2.8776],
#         [49.0000],
#         [ 1.2857],
#         [-2.3878],
#         [ 3.0000],
#         [-0.4286],
#         [-0.7959],
#         [ 2.5102],
#         [-1.0408],
#         [39.0000],
#         [-1.4082],])

# print(array_to_index(action_space, test_array))

# print(closest_value(action_space, 1.621313213))

# %%
# BATCH_SIZE is the number of transitions sampled from the replay buffer
# GAMMA is the discount factor as mentioned in the previous section
# EPS_START is the starting value of epsilon
# EPS_END is the final value of epsilon
# EPS_DECAY controls the rate of exponential decay of epsilon, higher means a slower decay
# TAU is the update rate of the target network
# LR is the learning rate of the ``AdamW`` optimizer
BATCH_SIZE = 128
GAMMA = 0.99
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 1000
TAU = 0.005
LR = 1e-4

# Create discrete actions for continuous action space
action_space = torch.linspace(-3, 3, 300, device=device)

# Get number of actions from gym action space
n_actions = action_space.size()[0]
# Get the number of state observations
state, info = env3.reset()
n_observations = len(state)

policy_net = DQN(n_observations, n_actions).to(device)
target_net = DQN(n_observations, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())

optimizer = optim.AdamW(policy_net.parameters(), lr=LR, amsgrad=True)
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return the largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1).indices.view(1, 1)
    else:
        # action_sample= action_integer(env3.action_space.sample())
        # print(env3.action_space.sample())
        action_sample = closest_value(action_space, torch.from_numpy(env3.action_space.sample()).to(device))
        # print(action_sample)
        return torch.tensor([[action_sample]], device=device, dtype=torch.float32)


episode_durations = []


def plot_durations(show_result=False):
    plt.figure(1)
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Cell In[7], line 22
#      20 n_actions = action_space.size()[0]
#      21 # Get the number of state observations
# ---> 22 state, info = env3.reset()
#      23 n_observations = len(state)
#      25 policy_net = DQN(n_observations, n_actions).to(device)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/wrappers/common.py:146, in TimeLimit.reset(self, seed, options)
#     136 """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#     137
#     138 Args:
#    (...)
#     143     The reset environment
#     144 """
#     145 self._elapsed_steps = 0
# --> 146 return super().reset(seed=seed, options=options)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/core.py:328, in Wrapper.reset(self, seed, options)
#     324 def reset(
#     325     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     326 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     327     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 328     return self.env.reset(seed=seed, options=options)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/wrappers/common.py:400, in OrderEnforcing.reset(self, seed, options)
#     398 """Resets the environment with `kwargs`."""
#     399 self._has_reset = True
# --> 400 return super().reset(seed=seed, options=options)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/core.py:328, in Wrapper.reset(self, seed, options)
#     324 def reset(
#     325     self, *, seed: int | None = None, options: dict[str, Any] | None = None
#     326 ) -> tuple[WrapperObsType, dict[str, Any]]:
#     327     """Uses the :meth:`reset` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 328     return self.env.reset(seed=seed, options=options)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/wrappers/common.py:293, in PassiveEnvChecker.reset(self, seed, options)
#     291 if self.checked_reset is False:
#     292     self.checked_reset = True
# --> 293     return env_reset_passive_checker(self.env, seed=seed, options=options)
#     294 else:
#     295     return self.env.reset(seed=seed, options=options)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:185, in env_reset_passive_checker(env, **kwargs)
#     180     logger.deprecation(
#     181         "Current gymnasium version requires that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information."
#     182     )
#     184 # Checks the result of env.reset with kwargs
# --> 185 result = env.reset(**kwargs)
#     187 if not isinstance(result, tuple):
#     188     logger.warn(
#     189         f"The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `{type(result)}`"
#     190     )
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_env.py:189, in MujocoEnv.reset(self, seed, options)
#     186 info = self._get_reset_info()
#     188 if self.render_mode == "human":
# --> 189     self.render()
#     190 return ob, info
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_env.py:164, in MujocoEnv.render(self)
#     160 def render(self):
#     161     """
#     162     Render a frame from the MuJoCo simulation as specified by the render_mode.
#     163     """
# --> 164     return self.mujoco_renderer.render(self.render_mode)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:706, in MujocoRenderer.render(self, render_mode)
#     693 def render(
#     694     self,
#     695     render_mode: Optional[str],
#     696 ):
#     697     """Renders a frame of the simulation in a specific format and camera view.
#     698
#     699     Args:
#    (...)
#     703         If render_mode is "rgb_array" or "depth_array" it returns a numpy array in the specified format. "human" render mode does not return anything.
#     704     """
# --> 706     viewer = self._get_viewer(render_mode=render_mode)
#     708     if render_mode in ["rgb_array", "depth_array"]:
#     709         return viewer.render(render_mode=render_mode, camera_id=self.camera_id)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:721, in MujocoRenderer._get_viewer(self, render_mode)
#     719 if self.viewer is None:
#     720     if render_mode == "human":
# --> 721         self.viewer = WindowViewer(
#     722             self.model,
#     723             self.data,
#     724             self.width,
#     725             self.height,
#     726             self.max_geom,
#     727             self._vopt,
#     728         )
#     729     elif render_mode in {"rgb_array", "depth_array"}:
#     730         self.viewer = OffScreenViewer(
#     731             self.model,
#     732             self.data,
#    (...)
#     736             self._vopt,
#     737         )
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:341, in WindowViewer.__init__(self, model, data, width, height, max_geom, visual_options)
#     338 glfw.set_scroll_callback(self.window, self._scroll_callback)
#     339 glfw.set_key_callback(self.window, self._key_callback)
# --> 341 super().__init__(model, data, width, height, max_geom, visual_options)
#     342 glfw.swap_interval(1)
#
# File ~/anaconda3/envs/tf/lib/python3.11/site-packages/gymnasium/envs/mujoco/mujoco_rendering.py:67, in BaseRender.__init__(self, model, data, width, height, max_geom, visual_options)
#      64 self.make_context_current()
#      66 # Keep in Mujoco Context
# ---> 67 self.con = mujoco.MjrContext(self.model, mujoco.mjtFontScale.mjFONTSCALE_150)
#      69 self._set_mujoco_buffer()
#
# FatalError: OpenGL version 1.5 or higher required

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = array_to_index(action_space, torch.cat(batch.action))
    # print(policy_net)
    # print(action_batch)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1).values
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1).values
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    criterion = nn.SmoothL1Loss()
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    # In-place gradient clipping
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %%
if torch.cuda.is_available() or torch.backends.mps.is_available():
    num_episodes = 1000
else:
    num_episodes = 50

for i_episode in range(num_episodes):
    # Initialize the environment and get its state
    state, info = env3.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    for t in count():
        action = select_action(state)
        # print(action)
        # print(action.item())
        # print(env3.step(0))

        observation, reward, terminated, truncated, _ = env3.step((action.item(),))
        reward = torch.tensor([reward], device=device)
        done = terminated or truncated

        if terminated:
            next_state = None
        else:
            next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the policy network)
        optimize_model()

        # Soft update of the target network's weights
        # θ′ ← τ θ + (1 −τ )θ′
        target_net_state_dict = target_net.state_dict()
        policy_net_state_dict = policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*TAU + target_net_state_dict[key]*(1-TAU)
        target_net.load_state_dict(target_net_state_dict)

        if done:
            episode_durations.append(t + 1)
            plot_durations()
            break

print('Complete')
plot_durations(show_result=True)
plt.ioff()
plt.show()
# Out:
# Complete
